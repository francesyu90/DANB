# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./clean_1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10838 entries, 0 to 10837
# Data columns (total 22 columns):
# Unnamed: 0         10838 non-null int64
# popularity         10838 non-null float64
# action             10838 non-null bool
# adventure          10838 non-null bool
# science_fiction    10838 non-null bool
# thriller           10838 non-null bool
# fantasy            10838 non-null bool
# crime              10838 non-null bool
# western            10838 non-null bool
# drama              10838 non-null bool
# family             10838 non-null bool
# animation          10838 non-null bool
# comedy             10838 non-null bool
# mystery            10838 non-null bool
# romance            10838 non-null bool
# war                10838 non-null bool
# history            10838 non-null bool
# music              10838 non-null bool
# horror             10838 non-null bool
# documentary        10838 non-null bool
# tv_movie           10838 non-null bool
# ...

# %%
df = df.drop(columns=['Unnamed: 0'], axis=1)

# %%
df
# Out:
#        popularity  action  adventure  science_fiction  thriller  fantasy  \
# 0       32.985763    True       True             True      True    False
# 1       28.419936    True       True             True      True    False
# 2       13.112507   False       True             True      True    False
# 3       11.173104    True       True             True     False     True
# 4        9.335014    True      False            False      True    False
# 5        9.110700   False       True            False      True    False
# 6        8.654359    True       True             True      True    False
# 7        7.667400   False       True             True     False    False
# 8        7.404165   False       True            False     False    False
# 9        6.326804   False      False            False     False    False
# 10       6.200282    True       True            False     False    False
# 11       6.189369    True       True             True     False     True
# ...

# %%
genres = df.columns.tolist()
del genres[0]
genres_array = np.array(genres)
genres_array
# Out:
# array(['action', 'adventure', 'science_fiction', 'thriller', 'fantasy',
#        'crime', 'western', 'drama', 'family', 'animation', 'comedy',
#        'mystery', 'romance', 'war', 'history', 'music', 'horror',
#        'documentary', 'tv_movie', 'foreign'], dtype='<U15')

# %%
action_mean = df.query('action == True')['popularity'].mean()
action_mean
# Out:
# 0.9262744358221475

# %%
adventure_mean = df.query('adventure == True')['popularity'].mean()
adventure_mean
# Out:
# 1.1542590441876273

# %%
science_fiction_mean = df.query('science_fiction == True')['popularity'].mean()
science_fiction_mean
# Out:
# 1.0015476501220504

# %%
thriller_mean = df.query('thriller == True')['popularity'].mean()
thriller_mean
# Out:
# 0.7415629927760577

# %%
fantasy_mean = df.query('fantasy == True')['popularity'].mean()
fantasy_mean
# Out:
# 0.9928397063318778

# %%
crime_mean = df.query('crime == True')['popularity'].mean()
crime_mean
# Out:
# 0.7449304453471195

# %%
western_mean = df.query('western == True')['popularity'].mean()
western_mean
# Out:
# 0.5906154787878787

# %%
drama_mean = df.query('drama == True')['popularity'].mean()
drama_mean
# Out:
# 0.5914953182773109

# %%
family_mean = df.query('family == True')['popularity'].mean()
family_mean
# Out:
# 0.786668393988627

# %%
animation_mean = df.query('animation == True')['popularity'].mean()
animation_mean
# Out:
# 0.8521816523605149

# %%
comedy_mean = df.query('comedy == True')['popularity'].mean()
comedy_mean
# Out:
# 0.5926933897097624

# %%
mystery_mean = df.query('mystery == True')['popularity'].mean()
mystery_mean
# Out:
# 0.6900121320987652

# %%
romance_mean = df.query('romance == True')['popularity'].mean()
romance_mean
# Out:
# 0.5920820490654205

# %%
war_mean = df.query('war == True')['popularity'].mean()
war_mean
# Out:
# 0.7276831481481482

# %%
history_mean = df.query('history == True')['popularity'].mean()
history_mean
# Out:
# 0.5759359431137724

# %%
music_mean = df.query('music == True')['popularity'].mean()
music_mean
# Out:
# 0.48732118382352935

# %%
horror_mean = df.query('horror == True')['popularity'].mean()
horror_mean
# Out:
# 0.4653566304215027

# %%
documentary_mean = df.query('documentary == True')['popularity'].mean()
documentary_mean
# Out:
# 0.18154509055876683

# %%
tv_movie_mean = df.query('tv_movie == True')['popularity'].mean()
tv_movie_mean
# Out:
# 0.2708957604790419

# %%
foreign_mean = df.query('foreign == True')['popularity'].mean()
foreign_mean
# Out:
# 0.19149632446808507

# %%
mean_list = [action_mean, adventure_mean, science_fiction_mean, thriller_mean, fantasy_mean, crime_mean, western_mean, 
             drama_mean, family_mean, animation_mean, comedy_mean, mystery_mean, romance_mean, war_mean, history_mean, 
             music_mean, horror_mean, documentary_mean, tv_movie_mean, foreign_mean]
mean_array = np.array(mean_list)
mean_array
# Out:
# array([0.92627444, 1.15425904, 1.00154765, 0.74156299, 0.99283971,
#        0.74493045, 0.59061548, 0.59149532, 0.78666839, 0.85218165,
#        0.59269339, 0.69001213, 0.59208205, 0.72768315, 0.57593594,
#        0.48732118, 0.46535663, 0.18154509, 0.27089576, 0.19149632])

# %%
plt.figure(figsize=(30,10))
plt.bar(genres_array, mean_array)
plt.xlabel('Genre')
plt.ylabel('Popularity')
index = np.arange(len(genres_array))
plt.xticks(index, genres_array, fontsize=12, rotation=30)
# for a,b in zip(genres_array, mean_array):
#     plt.text(a, b, str(b), rotation=30, fontsize=12)
plt.savefig('result/result.png')

# %%
zipped_list = zip(genres, mean_list)
sorted_zipped_array = np.array(sorted(zipped_list, key=lambda x: x[1]))
sorted_zipped_array
# Out:
# array([['documentary', '0.18154509055876683'],
#        ['foreign', '0.19149632446808507'],
#        ['tv_movie', '0.2708957604790419'],
#        ['horror', '0.4653566304215027'],
#        ['music', '0.48732118382352935'],
#        ['history', '0.5759359431137724'],
#        ['western', '0.5906154787878787'],
#        ['drama', '0.5914953182773109'],
#        ['romance', '0.5920820490654205'],
#        ['comedy', '0.5926933897097624'],
#        ['mystery', '0.6900121320987652'],
#        ['war', '0.7276831481481482'],
#        ['thriller', '0.7415629927760577'],
#        ['crime', '0.7449304453471195'],
#        ['family', '0.786668393988627'],
#        ['animation', '0.8521816523605149'],
#        ['action', '0.9262744358221475'],
#        ['fantasy', '0.9928397063318778'],
#        ['science_fiction', '1.0015476501220504'],
#        ['adventure', '1.1542590441876273']], dtype='<U19')
