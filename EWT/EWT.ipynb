# %%
import pandas as pd

# %%
df_city = pd.read_csv('../data/city_level.csv')

# %%
df_country = pd.read_csv('../data/global_level.csv')

# %%
df_city = df_city[['year', 'avg_temp']]

# %%
df_city = df_city.query('year >= 1750')

# %%
df_country = df_country.query('year <= 2013')

# %%
df_city_ma = df_city['avg_temp'].rolling(window=7).mean()

# %%
df_country_ma = df_country['avg_temp'].rolling(window=7).mean()

# %%
df_year = df_country['year']

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-whitegrid')

# %%
plt.plot(df_year, df_city_ma, label='Toronto')
plt.plot(df_year, df_country_ma, label='Global')

plt.ylim(3, 10)

plt.title("Exploring Weather Trends: Global Vs. Toronto")
plt.xlabel("Year")
plt.ylabel("Average Temperature")

plt.legend(loc=1)

plt.savefig('result/result.png')

# %%
########################

# %%
df_city['avg_temp'].describe()
# Out:
# count    264.000000
# mean       5.770682
# std        1.004007
# min       -1.100000
# 25%        5.267500
# 50%        5.780000
# 75%        6.272500
# max        8.700000
# Name: avg_temp, dtype: float64

# %%
df_country['avg_temp'].describe()
# Out:
# count    264.000000
# mean       8.359394
# std        0.575184
# min        5.780000
# 25%        8.077500
# 50%        8.365000
# 75%        8.700000
# max        9.730000
# Name: avg_temp, dtype: float64

# %%
df_city.query('avg_temp == -1.100000')
# Out:
#    year  avg_temp
# 9  1752      -1.1

# %%
df_country.query('avg_temp == 5.78')
# Out:
#    year  avg_temp
# 2  1752      5.78

# %%
df_city['avg_temp'].describe()
# Out:
# count    264.000000
# mean       5.770682
# std        1.004007
# min       -1.100000
# 25%        5.267500
# 50%        5.780000
# 75%        6.272500
# max        8.700000
# Name: avg_temp, dtype: float64

# %%
plt.plot(df_year, df_city['avg_temp'], label='Toronto')
plt.plot(df_year, df_country['avg_temp'], label='Global')

plt.title("Exploring Weather Trends: Global Vs. Toronto")
plt.xlabel("Year")
plt.ylabel("Average Temperature")

plt.legend(loc=1)

plt.savefig('result/result-1.png')

# %%
df_city_ma.describe()
# Out:
# count    258.000000
# mean       5.758029
# std        0.571386
# min        4.182857
# 25%        5.352143
# 50%        5.733571
# 75%        6.077143
# max        7.445714
# Name: avg_temp, dtype: float64

# %%
df_country_ma.describe()
# Out:
# count    258.000000
# mean       8.350781
# std        0.462115
# min        7.191429
# 25%        8.056071
# 50%        8.303571
# 75%        8.627500
# max        9.588571
# Name: avg_temp, dtype: float64
