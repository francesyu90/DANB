# %%
import pandas as pd

# %%
df_city = pd.read_csv('../data/city_level.csv')

# %%
df_country = pd.read_csv('../data/global_level.csv')

# %%
df_city = df_city[['year', 'avg_temp']]

# %%
df_city
# Out:
#      year  avg_temp
# 0    1743     -0.11
# 1    1744      8.38
# 2    1745     -3.96
# 3    1746       NaN
# 4    1747       NaN
# 5    1748       NaN
# 6    1749       NaN
# 7    1750      6.29
# 8    1751      6.84
# 9    1752     -1.10
# 10   1753      5.76
# 11   1754      5.94
# 12   1755      2.81
# 13   1756      6.37
# 14   1757      5.13
# 15   1758      4.37
# 16   1759      5.27
# 17   1760      3.74
# 18   1761      6.25
# 19   1762      5.79
# 20   1763      3.32
# 21   1764      5.76
# 22   1765      5.14
# 23   1766      6.27
# 24   1767      4.74
# 25   1768      4.81
# 26   1769      5.44
# 27   1770      5.35
# 28   1771      6.23
# 29   1772      5.93
# ..    ...       ...
# 241  1984      6.42
# 242  1985      6.13
# 243  1986      6.56
# 244  1987      7.46
# 245  1988      6.56
# 246  1989      5.70
# 247  1990      7.41
# 248  1991      7.55
# 249  1992      5.79
# 250  1993      5.87
# 251  1994      5.95
# 252  1995      6.38
# 253  1996      5.81
# 254  1997      6.00
# 255  1998      8.54
# 256  1999      7.75
# 257  2000      6.67
# 258  2001      7.76
# 259  2002      7.48
# 260  2003      6.02
# 261  2004      6.40
# 262  2005      7.22
# 263  2006      7.85
# 264  2007      7.07
# 265  2008      6.58
# 266  2009      6.28
# 267  2010      7.77
# 268  2011      7.30
# 269  2012      8.66
# 270  2013      8.46
#
# [271 rows x 2 columns]

# %%
df_country
# Out:
#      year  avg_temp
# 0    1750      8.72
# 1    1751      7.98
# 2    1752      5.78
# 3    1753      8.39
# 4    1754      8.47
# 5    1755      8.36
# 6    1756      8.85
# 7    1757      9.02
# 8    1758      6.74
# 9    1759      7.99
# 10   1760      7.19
# 11   1761      8.77
# 12   1762      8.61
# 13   1763      7.50
# 14   1764      8.40
# 15   1765      8.25
# 16   1766      8.41
# 17   1767      8.22
# 18   1768      6.78
# 19   1769      7.69
# 20   1770      7.69
# 21   1771      7.85
# 22   1772      8.19
# 23   1773      8.22
# 24   1774      8.77
# 25   1775      9.18
# 26   1776      8.30
# 27   1777      8.26
# 28   1778      8.54
# 29   1779      8.98
# ..    ...       ...
# 236  1986      8.83
# 237  1987      8.99
# 238  1988      9.20
# 239  1989      8.92
# 240  1990      9.23
# 241  1991      9.18
# 242  1992      8.84
# 243  1993      8.87
# 244  1994      9.04
# 245  1995      9.35
# 246  1996      9.04
# 247  1997      9.20
# 248  1998      9.52
# 249  1999      9.29
# 250  2000      9.20
# 251  2001      9.41
# 252  2002      9.57
# 253  2003      9.53
# 254  2004      9.32
# 255  2005      9.70
# 256  2006      9.53
# 257  2007      9.73
# 258  2008      9.43
# 259  2009      9.51
# 260  2010      9.70
# 261  2011      9.52
# 262  2012      9.51
# 263  2013      9.61
# 264  2014      9.57
# 265  2015      9.83
#
# [266 rows x 2 columns]

# %%
df_country = df_country.query('year <= 2013')

# %%
df_country
# Out:
#      year  avg_temp
# 0    1750      8.72
# 1    1751      7.98
# 2    1752      5.78
# 3    1753      8.39
# 4    1754      8.47
# 5    1755      8.36
# 6    1756      8.85
# 7    1757      9.02
# 8    1758      6.74
# 9    1759      7.99
# 10   1760      7.19
# 11   1761      8.77
# 12   1762      8.61
# 13   1763      7.50
# 14   1764      8.40
# 15   1765      8.25
# 16   1766      8.41
# 17   1767      8.22
# 18   1768      6.78
# 19   1769      7.69
# 20   1770      7.69
# 21   1771      7.85
# 22   1772      8.19
# 23   1773      8.22
# 24   1774      8.77
# 25   1775      9.18
# 26   1776      8.30
# 27   1777      8.26
# 28   1778      8.54
# 29   1779      8.98
# ..    ...       ...
# 234  1984      8.69
# 235  1985      8.66
# 236  1986      8.83
# 237  1987      8.99
# 238  1988      9.20
# 239  1989      8.92
# 240  1990      9.23
# 241  1991      9.18
# 242  1992      8.84
# 243  1993      8.87
# 244  1994      9.04
# 245  1995      9.35
# 246  1996      9.04
# 247  1997      9.20
# 248  1998      9.52
# 249  1999      9.29
# 250  2000      9.20
# 251  2001      9.41
# 252  2002      9.57
# 253  2003      9.53
# 254  2004      9.32
# 255  2005      9.70
# 256  2006      9.53
# 257  2007      9.73
# 258  2008      9.43
# 259  2009      9.51
# 260  2010      9.70
# 261  2011      9.52
# 262  2012      9.51
# 263  2013      9.61
#
# [264 rows x 2 columns]

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 2 columns):
# year        271 non-null int64
# avg_temp    267 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 4.3 KB

# %%
df_city['avg_temp'].unique()
# Out:
# array([-0.11,  8.38, -3.96,   nan,  6.29,  6.84, -1.1 ,  5.76,  5.94,
#         2.81,  6.37,  5.13,  4.37,  5.27,  3.74,  6.25,  5.79,  3.32,
#         5.14,  6.27,  4.74,  4.81,  5.44,  5.35,  6.23,  5.93,  6.22,
#         5.64,  6.64,  5.69,  5.23,  3.18,  6.1 ,  8.7 ,  5.96,  5.39,
#         5.11,  4.9 ,  4.83,  5.37,  6.  ,  5.7 ,  5.72,  5.15,  6.02,
#         6.05,  5.6 ,  5.48,  5.21,  6.03,  5.62,  5.85,  6.46,  6.49,
#         5.49,  5.66,  5.24,  5.38,  3.97,  5.31,  5.16,  4.52,  4.  ,
#         4.12,  4.84,  5.07,  5.08,  4.88,  4.86,  6.82,  5.46,  4.96,
#         5.9 ,  5.88,  6.16,  4.27,  4.89,  4.48,  5.33,  5.75,  5.8 ,
#         5.81,  6.47,  5.68,  5.18,  5.45,  4.26,  4.64,  5.54,  5.58,
#         5.36,  5.47,  4.59,  5.26,  3.47,  5.41,  6.48,  7.15,  6.19,
#         6.31,  5.97,  4.06,  5.29,  3.83,  5.17,  5.3 ,  4.39,  5.71,
#         6.28,  5.4 ,  5.12,  5.89,  6.59,  3.85,  5.83,  5.77,  6.43,
#         4.82,  6.68,  5.59,  3.91,  5.57,  6.54,  7.75,  6.5 ,  5.63,
#         4.34,  5.86,  6.44,  7.56,  6.62,  6.66,  5.55,  6.32,  6.91,
#         6.14,  5.06,  6.26,  5.19,  6.9 ,  6.18,  6.38,  7.31,  7.01,
#         7.51,  6.24,  6.97,  6.42,  6.4 ,  6.11,  5.98,  5.22,  7.23,
#         6.01,  6.75,  6.04,  6.78,  6.13,  6.56,  7.46,  7.41,  7.55,
#         5.87,  5.95,  8.54,  6.67,  7.76,  7.48,  7.22,  7.85,  7.07,
#         6.58,  7.77,  7.3 ,  8.66,  8.46])

# %%
df_city['avg_temp'].isnull().sum()
# Out:
# 4

# %%
city_mean = df_city['avg_temp'].mean()
city_mean
# Out:
# 5.721985018726592

# %%
df_city = df_city.fillna(city_mean)

# %%
df_city
# Out:
#      year  avg_temp
# 0    1743 -0.110000
# 1    1744  8.380000
# 2    1745 -3.960000
# 3    1746  5.721985
# 4    1747  5.721985
# 5    1748  5.721985
# 6    1749  5.721985
# 7    1750  6.290000
# 8    1751  6.840000
# 9    1752 -1.100000
# 10   1753  5.760000
# 11   1754  5.940000
# 12   1755  2.810000
# 13   1756  6.370000
# 14   1757  5.130000
# 15   1758  4.370000
# 16   1759  5.270000
# 17   1760  3.740000
# 18   1761  6.250000
# 19   1762  5.790000
# 20   1763  3.320000
# 21   1764  5.760000
# 22   1765  5.140000
# 23   1766  6.270000
# 24   1767  4.740000
# 25   1768  4.810000
# 26   1769  5.440000
# 27   1770  5.350000
# 28   1771  6.230000
# 29   1772  5.930000
# ..    ...       ...
# 241  1984  6.420000
# 242  1985  6.130000
# 243  1986  6.560000
# 244  1987  7.460000
# 245  1988  6.560000
# 246  1989  5.700000
# 247  1990  7.410000
# 248  1991  7.550000
# 249  1992  5.790000
# 250  1993  5.870000
# 251  1994  5.950000
# 252  1995  6.380000
# 253  1996  5.810000
# 254  1997  6.000000
# 255  1998  8.540000
# 256  1999  7.750000
# 257  2000  6.670000
# 258  2001  7.760000
# 259  2002  7.480000
# 260  2003  6.020000
# 261  2004  6.400000
# 262  2005  7.220000
# 263  2006  7.850000
# 264  2007  7.070000
# 265  2008  6.580000
# 266  2009  6.280000
# 267  2010  7.770000
# 268  2011  7.300000
# 269  2012  8.660000
# 270  2013  8.460000
#
# [271 rows x 2 columns]

# %%
df_country['avg_temp'].isnull().sum()
# Out:
# 0

# %%
df_city_ma = df_city['avg_temp'].rolling(window=7).mean()

# %%
df_country_ma = df_country['avg_temp'].rolling(window=7).mean()

# %%
df_year = df_country['year']

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(df_year, df_country_ma);

# %%
fig = plt.figure()
ax = plt.axes()

df_year = df_city['year']

ax.plot(df_year, df_city_ma);

# %%
df_year = df_city['year']

plt.plot(df_year, df_city_ma, label='Toronto')

df_year = df_country['year']

plt.plot(df_year, df_country_ma, label='Global')

plt.ylim(3, 10)

plt.title("Exploring Weather Trends: Global Vs. Toronto")
plt.xlabel("Year")
plt.ylabel("Average Temperature")

plt.legend(loc=1)

plt.savefig('result/result.png')
